# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import warnings
import statsmodels.api as sm
import pickle
from datetime import datetime
from dateutil.parser import parse
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# /Users/kevinzhao/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df_air = pickle.load(open('df_air2.p', 'rb'))

# %%
df_air = df_air.sort_values(['air_store_id', 'visit_date'])
df_air.index = df_air.visit_date

# %%
df_air_first = df_air[df_air.air_store_id == 'air_ba937bf13d40fb24']

# %% [markdown]
# ### Plot restaurant visits

# %% [markdown]
# air_ba937bf13d40fb24, 'air_0164b9927d20bcc3', 'air_0241aa3964b7f861'

# %%
plt.subplots(1,1,figsize=(20,6))
plt.plot(df_air_first.index, df_air_first.visitors)

# %% [markdown]
# ### AR model

# %%
def plot_ar_model(data, model, ar_value, restaurant_name):

    x = data.index
    y_true = data.visitors

    #plot actual usage
    plt.subplots(1,1,figsize=(20,6))
    plt.plot(x,y_true, label='Visitors')

    x_pred = x[ar_value:]
    y_pred = model.predict()

    #plot model prediction with AR
    plt.plot(x_pred,y_pred, color='red', label='AR')

    plt.title("Visits to Restaurant {} AR-{}".format(restaurant_name, ar_value))
    plt.xlabel("Date-Time", fontsize=16)
    plt.ylabel("Visitors", fontsize=16)
    plt.legend()

# %% [markdown]
# AR-7

# %%
AR7_model = sm.tsa.AR(df_air_first.visitors, freq=None).fit(maxlag=7)
print(AR7_model.params)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-195-c501b24a6345> in <module>()
# ----> 1 AR7_model = sm.tsa.AR(df_air_first.visitors, freq=None).fit(maxlag=7)
#       2 print(AR7_model.params)
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/ar_model.py in fit(self, maxlag, method, ic, trend, transparams, start_params, solver, maxiter, full_output, disp, callback, **kwargs)
#     558
#     559         if method == "cmle":     # do OLS
# --> 560             arfit = OLS(Y, X).fit()
#     561             params = arfit.params
#     562             self.nobs = nobs - k_ar
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     188                 (not hasattr(self, 'rank'))):
#     189
# --> 190                 self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     191                 self.normalized_cov_params = np.dot(self.pinv_wexog,
#     192                                         np.transpose(self.pinv_wexog))
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/tools/tools.py in pinv_extended(X, rcond)
#     340     X = np.asarray(X)
#     341     X = X.conjugate()
# --> 342     u, s, vt = np.linalg.svd(X, 0)
#     343     s_orig = np.copy(s)
#     344     m = u.shape[0]
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1442
#    1443         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1444         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1445         u = u.astype(result_t, copy=False)
#    1446         s = s.astype(_realType(result_t), copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#      96
#      97 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 98     raise LinAlgError("SVD did not converge")
#      99
#     100 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge

# %%
plot_ar_model(df_air_first, AR7_model, 7, 'air_ba937bf13d40fb24')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-1273c53afb5d> in <module>()
# ----> 1 plot_ar_model(df_air_first, AR7_model, 7, 'air_ba937bf13d40fb24')
#
# <ipython-input-156-a6dfdf7102c9> in plot_ar_model(data, model, ar_value, restaurant_name)
#      12
#      13     #plot model prediction with AR
# ---> 14     plt.plot(x_pred,y_pred, color='red', label='AR')
#      15
#      16     plt.title("Visits to Restaurant {} AR-{}".format(restaurant_name, ar_value))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1370         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1371
# -> 1372         for line in self._get_lines(*args, **kwargs):
#    1373             self.add_line(line)
#    1374             lines.append(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (150,) and (384,)

# %% [markdown]
# ### ARIMA model

# %%
from datetime import datetime, timedelta
from dateutil.relativedelta import *
import statsmodels.tsa.api as smt
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %%
arima = sm.tsa.statespace.SARIMAX(df_air_first.visitors,
                                  trend=None,
                                  order=(7,0,0),
                                  seasonal_order=(1,0,0,7),
                                  enforce_stationarity=False,
                                  enforce_invertibility=False).fit()

# %%
plt.subplots(1,1,figsize=(20,6))
plt.plot(df_air_first.index, df_air_first.visitors, label='Visitors')
plt.plot(df_air_first.index, arima.predict(), color='red', label='ARIMA')

# %% [markdown]
# ## Add exogenous variables

# %%
exogenous = df_air_first.loc[:,['holiday_flg','Monday','Tuesday','Wednesday','Thursday','Friday',
                                'Saturday']].astype(float)
endogenous = df_air_first.loc[:,'visitors'].astype(float)

# %%
sarimax_model = sm.tsa.statespace.SARIMAX(endog=endogenous,
                                  exog = exogenous,
                                  trend=None,
                                  order=(1,0,0),
                                  seasonal_order=(1,0,0,7),
                                  enforce_stationarity=True,
                                  enforce_invertibility=False).fit()

# %%
start_date = datetime(2017,4,22)
end_date = datetime(2017,5,31)

# %%
plt.subplots(1,1,figsize=(20,6))
plt.plot(df_air_first.index, df_air_first.visitors, label='Visitors')
plt.plot(df_air_first.loc[start_date.date():end_date.date(),:].index, sarimax_model.predict(start_date,end_date), color='red', label='SARIMAX')

# %% [markdown]
# ## Create predictions

# %%
#function to plot acf and pacf plots
def acf_pacf_plots(data, lags=None):
    plt.subplots(1, 3, figsize=(20,6))
    layout = (1, 3)
    raw  = plt.subplot2grid(layout, (0, 0))
    acf  = plt.subplot2grid(layout, (0, 1))
    pacf = plt.subplot2grid(layout, (0, 2))

    data.plot(ax=raw)
    smt.graphics.plot_acf(data, lags=lags, ax=acf)
    smt.graphics.plot_pacf(data, lags=lags, ax=pacf)
    sns.despine()
    plt.tight_layout()

# %%
#function to fit sarimax model for a store
def get_sarimax(data, store):
    
    df = data[data.air_store_id==store]
    exogenous = df.loc[:,['holiday_flg','Monday','Tuesday','Wednesday','Thursday','Friday',
                                'Saturday']].astype(float)
    endogenous = df.loc[:,'visitors'].astype(float)
    
    try:
        if df.shape[0] > 60:
            sarimax_model = sm.tsa.statespace.SARIMAX(endog=endogenous,
                                          exog = exogenous,
                                          trend=None,
                                          order=(0,1,2),
                                          seasonal_order=(1,0,7,7),
                                          enforce_stationarity=False,
                                          enforce_invertibility=False).fit()

        else:
            sarimax_model = sm.tsa.statespace.SARIMAX(endog=endogenous,
                                          exog = exogenous,
                                          trend=None,
                                          order=(1,0,0),
                                          seasonal_order=(1,0,0,7),
                                          enforce_stationarity=False,
                                          enforce_invertibility=False).fit()
    except ValueError:
        sarimax_model = sm.tsa.statespace.SARIMAX(endog=endogenous,
                                      exog = exogenous,
                                      trend=None,
                                      order=(2,0,1),
                                      seasonal_order=(1,0,0,7),
                                      enforce_stationarity=False,
                                      enforce_invertibility=False).fit()
    
    start_date = df.shape[0] - 40
    end_date = df.shape[0] -1
    
    df.iloc[-39:,4] = sarimax_model.predict(start_date,end_date).astype(int)
#     print('AIC score: {}'.format(sarimax_model.aic))
    
    return df

# %%
df_test = get_sarimax(df_air,'air_0328696196e46f18')

# %%
acf_pacf_plots(df_test.visitors, 50)

# %%
# 2017-04-29                   NaN      13.0            1            NaN
# 2017-04-30                   NaN       2.0            0            NaN
# 2017-05-01                   NaN       9.0            0            NaN
# 2017-05-02                   NaN      11.0            0            NaN
# 2017-05-03                   NaN       3.0            1            NaN
# 2017-05-04                   NaN       8.0            1            NaN
# 2017-05-05                   NaN      30.0            1            NaN
# 2017-05-06                   NaN      21.0            0            NaN
# 2017-05-07                   NaN       2.0            0            NaN
# 2017-05-08                   NaN       8.0            0            NaN
# 2017-05-09                   NaN      11.0            0            NaN
# 2017-05-10                   NaN      10.0            0            NaN
# 2017-05-11                   NaN      15.0            0            NaN
# 2017-05-12                   NaN      35.0            0            NaN
# 2017-05-13                   NaN      20.0            0            NaN
# 2017-05-14                   NaN       2.0            0            NaN
# 2017-05-15                   NaN       8.0            0            NaN
# 2017-05-16                   NaN      11.0            0            NaN
# 2017-05-17                   NaN      10.0            0            NaN
# 2017-05-18                   NaN      15.0            0            NaN
# 2017-05-19                   NaN      36.0            0            NaN
# 2017-05-20                   NaN      21.0            0            NaN
# 2017-05-21                   NaN       2.0            0            NaN
# 2017-05-22                   NaN       8.0            0            NaN
# 2017-05-23                   NaN      11.0            0            NaN
# 2017-05-24                   NaN      10.0            0            NaN
# 2017-05-25                   NaN      15.0            0            NaN
# 2017-05-26                   NaN      35.0            0            NaN
# 2017-05-27                   NaN      20.0            0            NaN
# 2017-05-28                   NaN       2.0            0            NaN
# 2017-05-29                   NaN       8.0            0            NaN
# 2017-05-30                   NaN      11.0            0            NaN
# 2017-05-31                   NaN      10.0            0            NaN
#
#            hpg_genre_name air_area_name  latitude    ...      Chinese Western  \
# visit_date                                           ...
# 2017-04-23            NaN           NaN       NaN    ...            0       0
# 2017-04-24            NaN           NaN       NaN    ...            0       0
# 2017-04-25            NaN           NaN       NaN    ...            0       0
# 2017-04-26            NaN           NaN       NaN    ...            0       0
# 2017-04-27            NaN           NaN       NaN    ...            0       0
# 2017-04-28            NaN           NaN       NaN    ...            0       0
# 2017-04-29            NaN           NaN       NaN    ...            0       0
# 2017-04-30            NaN           NaN       NaN    ...            0       0
# 2017-05-01            NaN           NaN       NaN    ...            0       0
# 2017-05-02            NaN           NaN       NaN    ...            0       0
# 2017-05-03            NaN           NaN       NaN    ...            0       0
# 2017-05-04            NaN           NaN       NaN    ...            0       0
# 2017-05-05            NaN           NaN       NaN    ...            0       0
# 2017-05-06            NaN           NaN       NaN    ...            0       0
# 2017-05-07            NaN           NaN       NaN    ...            0       0
# 2017-05-08            NaN           NaN       NaN    ...            0       0
# 2017-05-09            NaN           NaN       NaN    ...            0       0
# 2017-05-10            NaN           NaN       NaN    ...            0       0
# 2017-05-11            NaN           NaN       NaN    ...            0       0
# 2017-05-12            NaN           NaN       NaN    ...            0       0
# 2017-05-13            NaN           NaN       NaN    ...            0       0
# 2017-05-14            NaN           NaN       NaN    ...            0       0
# 2017-05-15            NaN           NaN       NaN    ...            0       0
# 2017-05-16            NaN           NaN       NaN    ...            0       0
# 2017-05-17            NaN           NaN       NaN    ...            0       0
# 2017-05-18            NaN           NaN       NaN    ...            0       0
# 2017-05-19            NaN           NaN       NaN    ...            0       0
# 2017-05-23          0
# 2017-05-24          1
# 2017-05-25          0
# 2017-05-26          0
# 2017-05-27          0
# 2017-05-28          0
# 2017-05-29          0
# 2017-05-30          0
# 2017-05-31          1
#
# [39 rows x 27 columns]

# %%
#function to make prediction for each restaurant and concat to prediction dataframe
def create_predictions(data):
    
    df = data[data.air_store_id == 'air_00a91d42b08b08d9']
    df = get_sarimax(df, 'air_00a91d42b08b08d9').iloc[-39:,:]
    
    for store in data.air_store_id.unique()[1:]:
        df_add = data[data.air_store_id==store]
        print('Restaurant {} is done'.format(store))
        df = pd.concat([df, get_sarimax(df_add, store).iloc[-39:,:]])
        
    return df

# %%
df_predictions = create_predictions(df_air)
# Out:
# Restaurant air_0164b9927d20bcc3 is done
# Restaurant air_0241aa3964b7f861 is done
# Restaurant air_0328696196e46f18 is done
# Restaurant air_034a3d5b40d5b1b1 is done
# Restaurant air_036d4f1ee7285390 is done
# Restaurant air_0382c794b73b51ad is done
# Restaurant air_03963426c9312048 is done
# Restaurant air_04341b588bde96cd is done
# Restaurant air_049f6d5b402a31b2 is done
# Restaurant air_04cae7c1bc9b2a0b is done
# Restaurant air_0585011fa179bcce is done
# Restaurant air_05c325d315cc17f5 is done
# Restaurant air_0647f17b4dc041c8 is done
# Restaurant air_064e203265ee5753 is done
# Restaurant air_066f0221b8a4d533 is done
# Restaurant air_06f95ac5c33aca10 is done
# Restaurant air_0728814bd98f7367 is done
# Restaurant air_0768ab3910f7967f is done
# Restaurant air_07b314d83059c4d2 is done
# Restaurant air_07bb665f9cdfbdfb is done
# Restaurant air_082908692355165e is done
# Restaurant air_083ddc520ea47e1e is done
# Restaurant air_0845d8395f30c6bb is done
# Restaurant air_084d98859256acf0 is done
# Restaurant air_0867f7bebad6a649 is done
# Restaurant air_08ba8cd01b3ba010 is done
# Restaurant air_08cb3c4ee6cd6a22 is done
# Restaurant air_08ef81d5b7a0d13f is done
# Restaurant air_08f994758a1e76d4 is done
# Restaurant air_09040f6df960ddb8 is done
# Restaurant air_0919d54f0c9a24b8 is done
# Restaurant air_09661c0f3259cc04 is done
# Restaurant air_09a845d5b5944b01 is done
# Restaurant air_09fd1f5c58583141 is done
# Restaurant air_0a74a5408a0b8642 is done
# Restaurant air_0b184ec04c741a6a is done
# Restaurant air_0b1e72d2d4422b20 is done
# Restaurant air_0b9038300f8b2b50 is done
# Restaurant air_0e1eae99b8723bc1 is done
# Restaurant air_0e7c11b9abc50163 is done
# Restaurant air_0f0cdeee6c9bf3d7 is done
# Restaurant air_0f2f96335f274801 is done
# Restaurant air_0f60e1576a7d397d is done
# Restaurant air_1033310359ceeac1 is done
# Restaurant air_10393f12e9069760 is done
# Restaurant air_105a7954e32dba9b is done
# Restaurant air_10713fbf3071c361 is done
# Restaurant air_10bbe8acd943d8f6 is done
# Restaurant air_12c4fb7a423df20d is done
# Restaurant air_138ee734ac79ff90 is done
# Restaurant air_138ff410757b845f is done
# Restaurant air_1408dd53f31a8a65 is done
# Restaurant air_142e78ba7001da9c is done
# Restaurant air_1509881b22965b34 is done
# Restaurant air_152c1f08d7d20e07 is done
# Restaurant air_15ae33469e9ea2dd is done
# Restaurant air_15e6e15c7ea2c162 is done
# Restaurant air_16179d43b6ee5fd8 is done
# Restaurant air_1653a6c513865af3 is done
# Restaurant air_168441ada3e878e1 is done
# Restaurant air_16c4cfddeb2cf69b is done
# Restaurant air_16cf0a73233896de is done
# Restaurant air_1707a3f18bb0da07 is done
# Restaurant air_17a6ab40f97fd4d8 is done
# Restaurant air_17bed6dbf7c8b0fc is done
# Restaurant air_1979eaff8189d086 is done
# Restaurant air_1ab60ce33bfed8a8 is done
# Restaurant air_1ae94f514a0bce13 is done
# Restaurant air_1ba4e87ef7422183 is done
# Restaurant air_1c0b150f9e696a5f is done
# Restaurant air_1c95a84924d72500 is done
# Restaurant air_1d1e8860ae04f8e9 is done
# Restaurant air_1d25ca6c76df48b4 is done
# Restaurant air_1d3f797dd1f7cf1c is done
# Restaurant air_1dd8f6f47480d1a2 is done
# Restaurant air_1dea9815ccd36620 is done
# Restaurant air_1e23210b584540e7 is done
# Restaurant air_1e665503b8474c55 is done
# Restaurant air_1eeff462acb24fb7 is done
# Restaurant air_1f1390a8be2272b3 is done
# Restaurant air_1f34e9beded2231a is done
# Restaurant air_1f7f8fa557bc0d55 is done
# Restaurant air_2009041dbf9264de is done
# Restaurant air_20619d21192aa571 is done
# Restaurant air_20add8092c9bb51d is done
# Restaurant air_2195cd5025a98033 is done
# Restaurant air_21f5052d5330528d is done
# Restaurant air_220cba70c890b119 is done
# Restaurant air_22682e965418936f is done
# Restaurant air_228f10bec0bda9c8 is done
# Restaurant air_232dcee6f7c51d37 is done
# Restaurant air_234d3dbf7f3d5a50 is done
# Restaurant air_23e1b11aee2a1407 is done
# Restaurant air_23ee674e91469086 is done
# Restaurant air_24b9b2a020826ede is done
# Restaurant air_24e8414b9b07decb is done
# Restaurant air_2545dd3a00f265e2 is done
# Restaurant air_256be208a979e023 is done
# Restaurant air_2570ccb93badde68 is done

# %%
df_predictions.shape
# Out:
# (32019, 27)

# %%
df_predictions['id'] = df_predictions['air_store_id'] + '_' + df_predictions['visit_date'].astype(str)

# %%
df_predictions = df_predictions[['id','visitors']]
df_predictions = df_predictions.reset_index().drop('visit_date', axis=1)

# %%
# pickle.dump(df_predictions, open('df_predictions.p','wb'))
df_predictions = pickle.load(open('df_predictions.p', 'rb'))

# %%
df_predictions[df_predictions.visitors<0]
# Out:
#                                     id  visitors
# 126    air_0328696196e46f18_2017-05-02      -1.0
# 140    air_0328696196e46f18_2017-05-16      -1.0
# 549    air_064e203265ee5753_2017-04-26     -13.0
# 556    air_064e203265ee5753_2017-05-03      -9.0
# 563    air_064e203265ee5753_2017-05-10     -13.0
# 570    air_064e203265ee5753_2017-05-17     -13.0
# 577    air_064e203265ee5753_2017-05-24     -13.0
# 584    air_064e203265ee5753_2017-05-31     -13.0
# 704    air_0768ab3910f7967f_2017-04-25      -3.0
# 711    air_0768ab3910f7967f_2017-05-02      -8.0
# 718    air_0768ab3910f7967f_2017-05-09      -5.0
# 725    air_0768ab3910f7967f_2017-05-16      -6.0
# 732    air_0768ab3910f7967f_2017-05-23      -6.0
# 739    air_0768ab3910f7967f_2017-05-30      -6.0
# 825    air_082908692355165e_2017-04-29      -2.0
# 1092   air_08ef81d5b7a0d13f_2017-04-23      -4.0
# 1099   air_08ef81d5b7a0d13f_2017-04-30      -3.0
# 1106   air_08ef81d5b7a0d13f_2017-05-07      -3.0
# 1113   air_08ef81d5b7a0d13f_2017-05-14      -3.0
# 1120   air_08ef81d5b7a0d13f_2017-05-21      -3.0
# 1127   air_08ef81d5b7a0d13f_2017-05-28      -3.0
# 1137   air_08f994758a1e76d4_2017-04-29      -2.0
# 1215   air_0919d54f0c9a24b8_2017-04-29     -14.0
# 1221   air_0919d54f0c9a24b8_2017-05-05     -11.0
# 1600   air_0f0cdeee6c9bf3d7_2017-04-24      -6.0
# 1607   air_0f0cdeee6c9bf3d7_2017-05-01      -7.0
# 1614   air_0f0cdeee6c9bf3d7_2017-05-08      -7.0
# 1621   air_0f0cdeee6c9bf3d7_2017-05-15      -7.0
# 1628   air_0f0cdeee6c9bf3d7_2017-05-22      -7.0
# 1635   air_0f0cdeee6c9bf3d7_2017-05-29      -7.0
# ...                                ...       ...
# 30264  air_f0c7272956e62f12_2017-04-23      -4.0
# 30271  air_f0c7272956e62f12_2017-04-30      -3.0
# 30278  air_f0c7272956e62f12_2017-05-07      -4.0
# 30285  air_f0c7272956e62f12_2017-05-14      -4.0
# 30292  air_f0c7272956e62f12_2017-05-21      -4.0
# 30299  air_f0c7272956e62f12_2017-05-28      -4.0
# 30501  air_f267dd70a6a6b5d3_2017-04-26      -1.0
# 30515  air_f267dd70a6a6b5d3_2017-05-10      -3.0
# 30522  air_f267dd70a6a6b5d3_2017-05-17      -4.0
# 30529  air_f267dd70a6a6b5d3_2017-05-24      -4.0
# 30536  air_f267dd70a6a6b5d3_2017-05-31      -4.0
# 30654  air_f3602e4fa2f12993_2017-04-23      -1.0
# 30662  air_f3602e4fa2f12993_2017-05-01      -1.0
# 30669  air_f3602e4fa2f12993_2017-05-08      -3.0
# 30676  air_f3602e4fa2f12993_2017-05-15      -3.0
# 30683  air_f3602e4fa2f12993_2017-05-22      -1.0
# 30811  air_f690c42545146e0a_2017-04-24      -2.0
# 30818  air_f690c42545146e0a_2017-05-01      -2.0
# 30825  air_f690c42545146e0a_2017-05-08      -2.0
# 30832  air_f690c42545146e0a_2017-05-15      -2.0
# 30839  air_f690c42545146e0a_2017-05-22      -2.0
# 30846  air_f690c42545146e0a_2017-05-29      -2.0
# 30972  air_f8233ad00755c35c_2017-04-29      -6.0
# 31551  air_fcfbdcf7b1f82c6e_2017-04-23      -2.0
# 31558  air_fcfbdcf7b1f82c6e_2017-04-30      -6.0
# 31565  air_fcfbdcf7b1f82c6e_2017-05-07      -3.0
# 31572  air_fcfbdcf7b1f82c6e_2017-05-14      -4.0
# 31579  air_fcfbdcf7b1f82c6e_2017-05-21      -4.0
# 31586  air_fcfbdcf7b1f82c6e_2017-05-28      -4.0
# 31947  air_ffcc2d5087e1b476_2017-04-29      -3.0
#
# [501 rows x 2 columns]

# %%
df_predictions.loc[:,'visitors'] = df_predictions.apply(
    lambda row: row['visitors'] if row['visitors']>0 else 0, axis=1)

# %%
df_predictions.to_csv('submission_012918.csv', index=False)

# %%
sample_submission.visitors[0]
# Out:
# numpy.int64

# %%
sample_submission.shape
# Out:
# (32019, 2)
